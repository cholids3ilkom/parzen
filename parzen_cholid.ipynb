# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2022-11-02 13:57:29--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   160MB/s    in 0.5s
#
# 2022-11-02 13:57:30 (160 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
#     - conda-package-handling==1.6.0=py37h7b6447c_0
#     - conda==4.8.2=py37_0
#     - cryptography==2.8=py37h1ba5d50_0
#     - idna==2.8=py37_0
#     - ld_impl_linux-64==2.33.1=h53a641e_7
#     - libedit==3.1.20181209=hc058e9b_0
#     - libffi==3.2.1=hd88cf55_4
#     - libgcc-ng==9.1.0=hdf63c60_0
#     - libstdcxx-ng==9.1.0=hdf63c60_0
#     - ncurses==6.2=he6710b0_0
#     - openssl==1.1.1d=h7b6447c_4
#     - pip==20.0.2=py37_1
#     - pycosat==0.6.3=py37h7b6447c_0
#     - pycparser==2.19=py37_0
#     - pyopenssl==19.1.0=py37_0
#     - pysocks==1.7.1=py37_0
#     - python==3.7.6=h0371630_2
#     - readline==7.0=h7b6447c_5
#     - requests==2.22.0=py37_1
#     - ruamel_yaml==0.15.87=py37h7b6447c_0
#     - setuptools==45.2.0=py37_0
#     - six==1.14.0=py37_0
#     - sqlite==3.31.1=h7b6447c_0
#     - tk==8.6.8=hbc83047_0
#     - tqdm==4.42.1=py_0
#     - urllib3==1.25.8=py37_0
#     - wheel==0.34.2=py37_0
#     - xz==5.2.4=h14c3975_4
#     - yaml==0.1.7=had09818_2
#     - zlib==1.2.11=h7b6447c_3
#
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      pkgs/main/linux-64::_libgcc_mutex-0.1-main
#   asn1crypto         pkgs/main/linux-64::asn1crypto-1.3.0-py37_0
#   ca-certificates    pkgs/main/linux-64::ca-certificates-2020.1.1-0
#   certifi            pkgs/main/linux-64::certifi-2019.11.28-py37_0
#   cffi               pkgs/main/linux-64::cffi-1.14.0-py37h2e261b9_0
#   chardet            pkgs/main/linux-64::chardet-3.0.4-py37_1003
#   conda              pkgs/main/linux-64::conda-4.8.2-py37_0
#   conda-package-han~ pkgs/main/linux-64::conda-package-handling-1.6.0-py37h7b6447c_0
#   cryptography       pkgs/main/linux-64::cryptography-2.8-py37h1ba5d50_0
#   idna               pkgs/main/linux-64::idna-2.8-py37_0
#   ld_impl_linux-64   pkgs/main/linux-64::ld_impl_linux-64-2.33.1-h53a641e_7
#   libedit            pkgs/main/linux-64::libedit-3.1.20181209-hc058e9b_0
#   libffi             pkgs/main/linux-64::libffi-3.2.1-hd88cf55_4
#   libgcc-ng          pkgs/main/linux-64::libgcc-ng-9.1.0-hdf63c60_0
#   libstdcxx-ng       pkgs/main/linux-64::libstdcxx-ng-9.1.0-hdf63c60_0
#   ncurses            pkgs/main/linux-64::ncurses-6.2-he6710b0_0
#   openssl            pkgs/main/linux-64::openssl-1.1.1d-h7b6447c_4
#   pip                pkgs/main/linux-64::pip-20.0.2-py37_1
#   pycosat            pkgs/main/linux-64::pycosat-0.6.3-py37h7b6447c_0
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py37_0
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-py37_0
#   pysocks            pkgs/main/linux-64::pysocks-1.7.1-py37_0
#   python             pkgs/main/linux-64::python-3.7.6-h0371630_2
#   readline           pkgs/main/linux-64::readline-7.0-h7b6447c_5
#   requests           pkgs/main/linux-64::requests-2.22.0-py37_1
#   ruamel_yaml        pkgs/main/linux-64::ruamel_yaml-0.15.87-py37h7b6447c_0
#   setuptools         pkgs/main/linux-64::setuptools-45.2.0-py37_0
#   six                pkgs/main/linux-64::six-1.14.0-py37_0
#   sqlite             pkgs/main/linux-64::sqlite-3.31.1-h7b6447c_0
#   tk                 pkgs/main/linux-64::tk-8.6.8-hbc83047_0
#   tqdm               pkgs/main/noarch::tqdm-4.42.1-py_0
#   urllib3            pkgs/main/linux-64::urllib3-1.25.8-py37_0
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37_0
#   xz                 pkgs/main/linux-64::xz-5.2.4-h14c3975_4
#   yaml               pkgs/main/linux-64::yaml-0.1.7-had09818_2
#   zlib               pkgs/main/linux-64::zlib-1.2.11-h7b6447c_3
#
#
# done
# done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas
#   Downloading pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#      |████████████████████████████████| 11.3 MB 5.1 MB/s
# Collecting pytz>=2017.3
#   Downloading pytz-2022.6-py2.py3-none-any.whl (498 kB)
#      |████████████████████████████████| 498 kB 69.4 MB/s
# Collecting numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10"
#   Downloading numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 37.8 MB/s
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
#      |████████████████████████████████| 247 kB 72.8 MB/s
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.14.0)
# Installing collected packages: pytz, numpy, python-dateutil, pandas
# Successfully installed numpy-1.21.6 pandas-1.3.5 python-dateutil-2.8.2 pytz-2022.6

# %%
# !which python
# !python --version
# Out:
# /usr/local/bin/python
# Python 3.7.6

# %%
# !conda install --channel defaults conda python=3.7 --yes
# !conda update --channel defaults --all --yes
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.10.11 |       h06a4308_0         124 KB
#     certifi-2022.9.24          |   py37h06a4308_0         154 KB
#     conda-22.9.0               |   py37h06a4308_0         878 KB
#     openssl-1.1.1q             |       h7f8727e_0         2.5 MB
#     toolz-0.11.2               |     pyhd3eb1b0_0          49 KB
#     ------------------------------------------------------------
#                                            Total:         3.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   toolz              pkgs/main/noarch::toolz-0.11.2-pyhd3eb1b0_0
#
# The following packages will be UPDATED:
#
#   ca-certificates                                2020.1.1-0 --> 2022.10.11-h06a4308_0
#   certifi                                 2019.11.28-py37_0 --> 2022.9.24-py37h06a4308_0
#   conda                                        4.8.2-py37_0 --> 22.9.0-py37h06a4308_0
#   openssl                                 1.1.1d-h7b6447c_4 --> 1.1.1q-h7f8727e_0
#
#
#
# Downloading and Extracting Packages
# openssl-1.1.1q       | 2.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.48s/it]
# certifi-2022.9.24    | 154 KB    | : 100% 1.0/1 [00:00<00:00, 11.40it/s]
# ca-certificates-2022 | 124 KB    | : 100% 1.0/1 [00:00<00:00, 14.40it/s]
# toolz-0.11.2         | 49 KB     | : 100% 1.0/1 [00:00<00:00, 10.23it/s]
# conda-22.9.0         | 878 KB    | : 100% 1.0/1 [00:00<00:00,  5.62it/s]
# done
# done
# done
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     brotlipy-0.7.0             |py37h27cfd23_1003         320 KB
#     cffi-1.15.1                |   py37h74dc2b5_0         227 KB
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          35 KB
#     conda-package-handling-1.9.0|   py37h5eee18b_1         945 KB
#     cryptography-38.0.1        |   py37h9ce1e76_0         1.3 MB
#     idna-3.4                   |   py37h06a4308_0          91 KB
#     ld_impl_linux-64-2.38      |       h1181459_1         654 KB
#     libffi-3.3                 |       he6710b0_2          50 KB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
#     libstdcxx-ng-11.2.0        |       h1234567_1         4.7 MB
#     ncurses-6.3                |       h5eee18b_3         781 KB
#     pip-22.2.2                 |   py37h06a4308_0         2.3 MB
#     pycosat-0.6.3              |   py37h27cfd23_0          81 KB
#     pycparser-2.21             |     pyhd3eb1b0_0          94 KB
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          50 KB
#     pysocks-1.7.1              |           py37_1          27 KB
#     python-3.7.13              |       haa1d7c7_1        40.7 MB
#     readline-8.2               |       h5eee18b_0         357 KB
#     requests-2.28.1            |   py37h06a4308_0          92 KB
#     ruamel_yaml-0.15.100       |   py37h27cfd23_0         253 KB
#     setuptools-65.5.0          |   py37h06a4308_0         1.1 MB
#     sqlite-3.39.3              |       h5082296_0         1.1 MB
#     tk-8.6.12                  |       h1ccaba5_0         3.0 MB
#     tqdm-4.64.1                |   py37h06a4308_0         126 KB
#     urllib3-1.26.12            |   py37h06a4308_0         181 KB
#     wheel-0.37.1               |     pyhd3eb1b0_0          33 KB
#     xz-5.2.6                   |       h5eee18b_0         394 KB
#     yaml-0.2.5                 |       h7b6447c_0          75 KB
#     zlib-1.2.13                |       h5eee18b_0         103 KB
#     ------------------------------------------------------------
#                                            Total:        64.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      pkgs/main/linux-64::_openmp_mutex-5.1-1_gnu None
#   brotlipy           pkgs/main/linux-64::brotlipy-0.7.0-py37h27cfd23_1003 None
#   charset-normalizer pkgs/main/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0 None
#   libgomp            pkgs/main/linux-64::libgomp-11.2.0-h1234567_1 None
#
# The following packages will be REMOVED:
#
#   asn1crypto-1.3.0-py37_0
#   chardet-3.0.4-py37_1003
#   libedit-3.1.20181209-hc058e9b_0
#   six-1.14.0-py37_0
#
# The following packages will be UPDATED:
#
#   cffi                                1.14.0-py37h2e261b9_0 --> 1.15.1-py37h74dc2b5_0 None
#   conda-package-han~                   1.6.0-py37h7b6447c_0 --> 1.9.0-py37h5eee18b_1 None
#   cryptography                           2.8-py37h1ba5d50_0 --> 38.0.1-py37h9ce1e76_0 None
#   idna                                           2.8-py37_0 --> 3.4-py37h06a4308_0 None
#   ld_impl_linux-64                        2.33.1-h53a641e_7 --> 2.38-h1181459_1 None
#   libffi                                   3.2.1-hd88cf55_4 --> 3.3-he6710b0_2 None
#   libgcc-ng                                9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1 None
#   libstdcxx-ng                             9.1.0-hdf63c60_0 --> 11.2.0-h1234567_1 None
#   ncurses                                    6.2-he6710b0_0 --> 6.3-h5eee18b_3 None
#   pip                                         20.0.2-py37_1 --> 22.2.2-py37h06a4308_0 None
#   pycparser          pkgs/main/linux-64::pycparser-2.19-py~ --> pkgs/main/noarch::pycparser-2.21-pyhd3eb1b0_0 None
#   pyopenssl          pkgs/main/linux-64::pyopenssl-19.1.0-~ --> pkgs/main/noarch::pyopenssl-22.0.0-pyhd3eb1b0_0 None
#   pysocks                                      1.7.1-py37_0 --> 1.7.1-py37_1 None
#   python                                   3.7.6-h0371630_2 --> 3.7.13-haa1d7c7_1 None
#   readline                                   7.0-h7b6447c_5 --> 8.2-h5eee18b_0 None
#   requests                                    2.22.0-py37_1 --> 2.28.1-py37h06a4308_0 None
#   ruamel_yaml                        0.15.87-py37h7b6447c_0 --> 0.15.100-py37h27cfd23_0 None
#   setuptools                                  45.2.0-py37_0 --> 65.5.0-py37h06a4308_0 None
#   sqlite                                  3.31.1-h7b6447c_0 --> 3.39.3-h5082296_0 None
#   tk                                       8.6.8-hbc83047_0 --> 8.6.12-h1ccaba5_0 None
#   tqdm                   pkgs/main/noarch::tqdm-4.42.1-py_0 --> pkgs/main/linux-64::tqdm-4.64.1-py37h06a4308_0 None
#   urllib3                                     1.25.8-py37_0 --> 1.26.12-py37h06a4308_0 None
#   wheel              pkgs/main/linux-64::wheel-0.34.2-py37~ --> pkgs/main/noarch::wheel-0.37.1-pyhd3eb1b0_0 None
#   xz                                       5.2.4-h14c3975_4 --> 5.2.6-h5eee18b_0 None
#   yaml                                     0.1.7-had09818_2 --> 0.2.5-h7b6447c_0 None
#   zlib                                    1.2.11-h7b6447c_3 --> 1.2.13-h5eee18b_0 None
#
# The following packages will be DOWNGRADED:
#
#   pycosat                              0.6.3-py37h7b6447c_0 --> 0.6.3-py37h27cfd23_0 None
#
#
#
# Downloading and Extracting Packages
# pycparser-2.21       | 94 KB     | : 100% 1.0/1 [00:00<00:00,  7.33it/s]
# pysocks-1.7.1        | 27 KB     | : 100% 1.0/1 [00:00<00:00, 12.37it/s]
# idna-3.4             | 91 KB     | : 100% 1.0/1 [00:00<00:00,  9.76it/s]
# readline-8.2         | 357 KB    | : 100% 1.0/1 [00:00<00:00,  8.80it/s]
# cffi-1.15.1          | 227 KB    | : 100% 1.0/1 [00:00<00:00, 11.50it/s]
# charset-normalizer-2 | 35 KB     | : 100% 1.0/1 [00:00<00:00, 12.08it/s]
# tqdm-4.64.1          | 126 KB    | : 100% 1.0/1 [00:00<00:00, 10.29it/s]
# pyopenssl-22.0.0     | 50 KB     | : 100% 1.0/1 [00:00<00:00, 12.66it/s]
# python-3.7.13        | 40.7 MB   | : 100% 1.0/1 [00:02<00:00,  2.23s/it]
# pip-22.2.2           | 2.3 MB    | : 100% 1.0/1 [00:00<00:00,  3.10it/s]
# libgcc-ng-11.2.0     | 5.3 MB    | : 100% 1.0/1 [00:00<00:00,  2.23it/s]
# tk-8.6.12            | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  3.44it/s]
# ld_impl_linux-64-2.3 | 654 KB    | : 100% 1.0/1 [00:00<00:00,  9.10it/s]
# ncurses-6.3          | 781 KB    | : 100% 1.0/1 [00:00<00:00,  2.26it/s]
# cryptography-38.0.1  | 1.3 MB    | : 100% 1.0/1 [00:00<00:00,  7.64it/s]
# yaml-0.2.5           | 75 KB     | : 100% 1.0/1 [00:00<00:00, 13.96it/s]
# conda-package-handli | 945 KB    | : 100% 1.0/1 [00:00<00:00,  9.43it/s]
# brotlipy-0.7.0       | 320 KB    | : 100% 1.0/1 [00:00<00:00, 12.30it/s]
# requests-2.28.1      | 92 KB     | : 100% 1.0/1 [00:00<00:00, 12.46it/s]
# libstdcxx-ng-11.2.0  | 4.7 MB    | : 100% 1.0/1 [00:00<00:00,  4.16it/s]
# zlib-1.2.13          | 103 KB    | : 100% 1.0/1 [00:00<00:00, 15.11it/s]
# ruamel_yaml-0.15.100 | 253 KB    | : 100% 1.0/1 [00:00<00:00,  9.46it/s]
# xz-5.2.6             | 394 KB    | : 100% 1.0/1 [00:00<00:00, 10.98it/s]
# setuptools-65.5.0    | 1.1 MB    | : 100% 1.0/1 [00:00<00:00,  7.21it/s]
# _openmp_mutex-5.1    | 21 KB     | : 100% 1.0/1 [00:00<00:00, 14.59it/s]
# sqlite-3.39.3        | 1.1 MB    | : 100% 1.0/1 [00:00<00:00, 10.75it/s]
# urllib3-1.26.12      | 181 KB    | : 100% 1.0/1 [00:00<00:00, 13.63it/s]
# libffi-3.3           | 50 KB     | : 100% 1.0/1 [00:00<00:00, 16.77it/s]
# wheel-0.37.1         | 33 KB     | : 100% 1.0/1 [00:00<00:00, 16.30it/s]
# pycosat-0.6.3        | 81 KB     | : 100% 1.0/1 [00:00<00:00, 13.81it/s]
# libgomp-11.2.0       | 474 KB    | : 100% 1.0/1 [00:00<00:00, 11.81it/s]
# done
# done
# done
# Retrieving notices: ...working... done

# %%
# %matplotlib inline
import mpl_toolkits.mplot3d
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, combinations
fig = plt.figure(figsize=(7,7))
ax = fig.gca(projection='3d')
ax.set_box_aspect([1,1,1])
def set_axes_equal(ax: plt.Axes):

# Plot Points

# samples within the cube
X_inside = np.array([[0,0,0],[0.2,0.2,0.2],[0.1, -0.1, -0.3]])

X_outside = np.array([[-1.2,0.3,-0.3],[0.8,-0.82,-0.9],[1, 0.6, -0.7],
                  [0.8,0.7,0.2],[0.7,-0.8,-0.45],[-0.3, 0.6, 0.9],
                  [0.7,-0.6,-0.8]])

for row in X_inside:
    ax.scatter(row[0], row[1], row[2], color="r", s=50, marker='^')

for row in X_outside:
    ax.scatter(row[0], row[1], row[2], color="k", s=50)

# Plot Cube
h = [-0.5, 0.5]
for s, e in combinations(np.array(list(product(h,h,h))), 2):
    if np.sum(np.abs(s-e)) == h[1]-h[0]:
        ax.plot3D(*zip(s,e), color="g")

ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)

plt.show()
# Out:
#   File "<ipython-input-17-9632695b3ac1>", line 14
#     X_inside = np.array([[0,0,0],[0.2,0.2,0.2],[0.1, -0.1, -0.3]])
#            ^
# IndentationError: expected an indented block

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.7/dist-packages
# Out:
# absl
# absl_py-1.3.0.dist-info
# aeppl
# aeppl-0.0.33.dist-info
# aesara
# aesara-2.7.9.dist-info
# aiohttp
# aiohttp-3.8.3.dist-info
# aiosignal
# aiosignal-1.2.0.dist-info
# alabaster
# alabaster-0.7.12.dist-info
# albumentations
# albumentations-1.2.1.dist-info
# altair
# altair-4.2.0.dist-info
# apiclient
# appdirs-1.4.4.dist-info
# appdirs.py
# apt
# apt_inst.cpython-37m-x86_64-linux-gnu.so
# apt_inst.pyi
# apt_pkg.cpython-37m-x86_64-linux-gnu.so
# apt_pkg.pyi
# aptsources
# arviz
# arviz-0.12.1.dist-info
# astor
# astor-0.8.1.dist-info
# astropy
# astropy-4.3.1.dist-info
# astunparse
# astunparse-1.6.3.dist-info
# asynctest
# asynctest-0.13.0.dist-info
# async_timeout
# async_timeout-4.0.2.dist-info
# atari_py
# atari_py-0.2.9.dist-info
# atari_py.libs
# atomicwrites
# atomicwrites-1.4.1.dist-info
# attr
# attrs
# attrs-22.1.0.dist-info
# audioread
# audioread-3.0.0.dist-info
# autograd
# autograd-1.5.dist-info
# babel
# Babel-2.10.3.dist-info
# backcall
# backcall-0.2.0.dist-info
# beautifulsoup4-4.6.3.dist-info
# bin
# bleach
# bleach-5.0.1.dist-info
# blis
# blis-0.7.9.dist-info
# bokeh
# bokeh-2.3.3.dist-info
# branca
# branca-0.5.0.dist-info
# bs4
# bs4-0.0.1.dist-info
# bson
# cachecontrol
# CacheControl-0.12.11.dist-info
# cached_property-1.5.2.dist-info
# cached_property.py
# cachetools
# cachetools-4.2.4.dist-info
# caffe2
# catalogue
# catalogue-2.0.8.dist-info
# certifi
# certifi-2022.9.24.dist-info
# cffi
# cffi-1.15.1.dist-info
# _cffi_backend.cpython-37m-x86_64-linux-gnu.so
# cftime
# cftime-1.6.2.dist-info
# chardet
# chardet-3.0.4.dist-info
# charset_normalizer
# charset_normalizer-2.1.1.dist-info
# clang
# click
# click-7.1.2.dist-info
# client
# clikit
# clikit-0.6.2.dist-info
# cloudpickle
# cloudpickle-1.5.0.dist-info
# cmake
# cmake-3.22.6.dist-info
# cmdstanpy
# cmdstanpy-1.0.8.dist-info
# colab
# colorcet
# colorcet-3.0.1.dist-info
# colorlover
# colorlover-0.3.0.dist-info
# community
# community-1.0.0b1.dist-info
# confection
# confection-0.0.3.dist-info
# cons
# cons-0.4.5.dist-info
# contextlib2-0.5.5.dist-info
# contextlib2.py
# convertdate
# convertdate-2.4.0.dist-info
# crashtest
# crashtest-0.3.1.dist-info
# crcmod
# crcmod-1.7.dist-info
# csimdjson.cpython-37m-x86_64-linux-gnu.so
# cufflinks
# cufflinks-0.17.3.dist-info
# cv2
# _cvxcore.cpython-37m-x86_64-linux-gnu.so
# cvxopt
# cvxopt-1.3.0.dist-info
# cvxopt.libs
# cvxpy
# cvxpy-1.2.1.dist-info
# cycler-0.11.0.dist-info
# cycler.py
# cymem
# cymem-2.0.7.dist-info
# Cython
# Cython-0.29.32.dist-info
# cython.py
# daft-0.0.4.dist-info
# daft.py
# dask
# dask-2022.2.0.dist-info
# datascience
# datascience-0.17.5.dist-info
# dateutil
# debugpy
# debugpy-1.0.0.dist-info
# decorator-4.4.2.dist-info
# decorator.py
# defusedxml
# defusedxml-0.7.1.dist-info
# descartes
# descartes-1.1.0.dist-info
# dill
# dill-0.3.6.dist-info
# distributed
# distributed-2022.2.0.dist-info
# _distutils_hack
# distutils-precedence.pth
# dlib
# dlib-19.24.0.dist-info
# _dlib_pybind11.cpython-37m-x86_64-linux-gnu.so
# dm_tree-0.1.7.dist-info
# dns
# dnspython-2.2.1.dist-info
# docs
# docutils
# docutils-0.17.1.dist-info
# dopamine
# dopamine_rl-1.0.5.dist-info
# dot_parser.py
# earthengine_api-0.1.329.dist-info
# easydict
# easydict-1.10.dist-info
# ecos
# ecos-2.0.10.dist-info
# _ecos.cpython-37m-x86_64-linux-gnu.so
# editdistance
# editdistance-0.5.3.dist-info
# ee
# en_core_web_sm
# en_core_web_sm-3.4.1.dist-info
# entrypoints-0.4.dist-info
# entrypoints.py
# ephem
# ephem-4.1.3.dist-info
# erfa
# etils
# etils-0.8.0.dist-info
# etuples
# etuples-0.3.8.dist-info
# et_xmlfile
# et_xmlfile-1.1.0.dist-info
# examples
# fa2
# fa2-0.3.5.dist-info
# fastai
# fastai-2.7.9.dist-info
# fastcore
# fastcore-1.5.27.dist-info
# fastdownload
# fastdownload-0.0.7.dist-info
# fastdtw
# fastdtw-0.3.4.dist-info
# fastjsonschema
# fastjsonschema-2.16.2.dist-info
# fastprogress
# fastprogress-1.0.3.dist-info
# fastrlock
# fastrlock-0.8.dist-info
# feather
# feather_format-0.4.1.dist-info
# filelock
# filelock-3.8.0.dist-info
# firebase_admin
# firebase_admin-4.4.0.dist-info
# fix_yahoo_finance
# fix_yahoo_finance-0.0.22.dist-info
# flask
# Flask-1.1.4.dist-info
# flatbuffers
# flatbuffers-1.12.dist-info
# folium
# folium-0.12.1.post1.dist-info
# frozenlist
# frozenlist-1.3.1.dist-info
# fsspec
# fsspec-2022.10.0.dist-info
# future
# future-0.16.0.dist-info
# gast
# gast-0.4.0.dist-info
# GDAL-2.2.2.dist-info
# gdalconst.py
# gdalnumeric.py
# gdal.py
# gdown
# gdown-4.4.0.dist-info
# gensim
# gensim-3.6.0.dist-info
# geographiclib
# geographiclib-1.52.dist-info
# geopy
# geopy-1.17.0.dist-info
# gin
# gin_config-0.5.0.dist-info
# glob2
# glob2-0.7.dist-info
# gnm.py
# google
# google-2.0.3.dist-info
# googleapiclient
# google_api_core-1.31.6.dist-info
# google_api_core-1.31.6-py3.10-nspkg.pth
# google_api_python_client-1.12.11.dist-info
# googleapis_common_protos-1.56.4.dist-info
# googleapis_common_protos-1.56.4-py3.10-nspkg.pth
# google_auth-1.35.0.dist-info
# google_auth-1.35.0-py3.9-nspkg.pth
# google_auth_httplib2-0.0.4.dist-info
# google_auth_httplib2.py
# google_auth_oauthlib
# google_auth_oauthlib-0.4.6.dist-info
# google_cloud_bigquery-1.21.0.dist-info
# google_cloud_bigquery-1.21.0-py3.6-nspkg.pth
# google_cloud_bigquery_storage-1.1.2.dist-info
# google_cloud_bigquery_storage-1.1.2-py3.10-nspkg.pth
# google_cloud_core-1.0.3.dist-info
# google_cloud_core-1.0.3-py3.6-nspkg.pth
# google_cloud_datastore-1.8.0.dist-info
# google_cloud_datastore-1.8.0-py3.6-nspkg.pth
# google_cloud_firestore-1.7.0.dist-info
# google_cloud_firestore-1.7.0-py3.8-nspkg.pth
# google_cloud_language-1.2.0.dist-info
# google_cloud_language-1.2.0-py3.6-nspkg.pth
# google_cloud_storage-1.18.1.dist-info
# google_cloud_storage-1.18.1-py3.7-nspkg.pth
# google_cloud_translate-1.5.0.dist-info
# google_cloud_translate-1.5.0-py3.6-nspkg.pth
# google_colab-1.0.0.dist-info
# google_colab-1.0.0-py3.7-nspkg.pth
# google_drive_downloader
# googledrivedownloader-0.4.dist-info
# google_pasta-0.2.0.dist-info
# google_resumable_media-0.4.1.dist-info
# google_resumable_media-0.4.1-py3.6-nspkg.pth
# googlesearch
# graphviz
# graphviz-0.10.1.dist-info
# greenlet
# greenlet-1.1.3.post0.dist-info
# gridfs
# grpc
# grpcio-1.50.0.dist-info
# gspread
# gspread-3.4.2.dist-info
# gspread_dataframe-3.0.8.dist-info
# gspread_dataframe.py
# gym
# gym-0.25.2.dist-info
# gym_notices
# gym_notices-0.0.8.dist-info
# h5py
# h5py-3.1.0.dist-info
# h5py.libs
# HeapDict-1.0.1.dist-info
# heapdict.py
# helper
# hijri_converter
# hijri_converter-2.2.4.dist-info
# holidays
# holidays-0.16.dist-info
# holoviews
# holoviews-1.14.9.dist-info
# html5lib
# html5lib-1.0.1.dist-info
# httpimport-0.5.18.dist-info
# httpimport.py
# httplib2
# httplib2-0.17.4.dist-info
# httplib2shim
# httplib2shim-0.0.3.dist-info
# httpstan
# httpstan-4.6.1.dist-info
# humanize
# humanize-0.5.1.dist-info
# hyperopt
# hyperopt-0.1.2.dist-info
# idna
# idna-2.10.dist-info
# imageio
# imageio-2.9.0.dist-info
# imagesize
# imagesize-1.4.1.dist-info
# imagesize.py
# imbalanced_learn-0.8.1.dist-info
# imblearn
# imblearn-0.0.dist-info
# imgaug
# imgaug-0.4.0.dist-info
# importlib_metadata
# importlib_metadata-4.13.0.dist-info
# importlib_resources
# importlib_resources-5.10.0.dist-info
# imutils
# imutils-0.5.4.dist-info
# inflect-2.1.0.dist-info
# inflect.py
# intel_openmp-2022.2.0.dist-info
# intervaltree
# intervaltree-2.1.0.dist-info
# ipykernel
# ipykernel-5.3.4.dist-info
# ipykernel_launcher.py
# IPython
# ipython-7.9.0.dist-info
# ipython_genutils
# ipython_genutils-0.2.0.dist-info
# ipython_sql-0.3.9.dist-info
# ipywidgets
# ipywidgets-7.7.1.dist-info
# isympy.py
# itsdangerous
# itsdangerous-1.1.0.dist-info
# jax
# jax-0.3.23.dist-info
# jaxlib
# jaxlib-0.3.22+cuda11.cudnn805.dist-info
# jieba
# jieba-0.42.1.dist-info
# jinja2
# Jinja2-2.11.3.dist-info
# joblib
# joblib-1.2.0.dist-info
# jpeg4py
# jpeg4py-0.1.4.dist-info
# jsonschema
# jsonschema-4.3.3.dist-info
# jupyter_client
# jupyter_client-6.1.12.dist-info
# jupyter_console
# jupyter_console-6.1.0.dist-info
# jupyter_core
# jupyter_core-4.11.2.dist-info
# jupyterlab_plotly
# jupyterlab_widgets
# jupyterlab_widgets-3.0.3.dist-info
# jupyter.py
# kaggle
# kaggle-1.5.12.dist-info
# kanren
# kapre
# kapre-0.3.7.dist-info
# keras
# keras-2.9.0.dist-info
# keras_preprocessing
# Keras_Preprocessing-1.1.2.dist-info
# keras_vis-0.4.1.dist-info
# kiwisolver
# kiwisolver-1.4.4.dist-info
# korean_lunar_calendar
# korean_lunar_calendar-0.3.1.dist-info
# langcodes
# langcodes-3.3.0.dist-info
# libclang-14.0.6.dist-info
# libfuturize
# libpasteurize
# librosa
# librosa-0.8.1.dist-info
# lightgbm
# lightgbm-2.2.3.dist-info
# llvmlite
# llvmlite-0.39.1.dist-info
# lmdb
# lmdb-0.99.dist-info
# locket
# locket-1.0.0.dist-info
# logical_unification-0.4.5.dist-info
# lunarcalendar
# LunarCalendar-0.0.9.dist-info
# lxml
# lxml-4.9.1.dist-info
# markdown
# Markdown-3.4.1.dist-info
# markupsafe
# MarkupSafe-2.0.1.dist-info
# marshmallow
# marshmallow-3.18.0.dist-info
# matplotlib
# matplotlib-3.2.2.dist-info
# matplotlib-3.2.2-py3.7-nspkg.pth
# matplotlib.libs
# matplotlib_venn
# matplotlib_venn-0.11.7.dist-info
# miniKanren-1.0.3.dist-info
# missingno
# missingno-0.5.1.dist-info
# mistune-0.8.4.dist-info
# mistune.py
# mizani
# mizani-0.7.3.dist-info
# mkl-2019.0.dist-info
# mlxtend
# mlxtend-0.14.0.dist-info
# more_itertools
# more_itertools-9.0.0.dist-info
# moviepy
# moviepy-0.2.3.5.dist-info
# mpl_toolkits
# mpmath
# mpmath-1.2.1.dist-info
# msgpack
# msgpack-1.0.4.dist-info
# multidict
# multidict-6.0.2.dist-info
# multipledispatch
# multipledispatch-0.6.0.dist-info
# multitasking
# multitasking-0.0.11.dist-info
# murmurhash
# murmurhash-1.0.9.dist-info
# music21
# music21-5.5.0.dist-info
# natsort
# natsort-5.5.0.dist-info
# nbconvert
# nbconvert-5.6.1.dist-info
# nbformat
# nbformat-5.7.0.dist-info
# netCDF4
# netCDF4-1.6.1.dist-info
# netCDF4.libs
# networkx
# networkx-2.6.3.dist-info
# nibabel
# nibabel-3.0.2.dist-info
# nisext
# nltk
# nltk-3.7.dist-info
# notebook
# notebook-5.5.0.dist-info
# numba
# numba-0.56.3.dist-info
# numbergen
# numexpr
# numexpr-2.8.4.dist-info
# numpy
# numpy-1.21.6.dist-info
# numpy.libs
# oauth2client
# oauth2client-4.1.3.dist-info
# oauthlib
# oauthlib-3.2.2.dist-info
# ogr.py
# okgrade
# okgrade-0.4.3.dist-info
# opencv_contrib_python-4.6.0.66.dist-info
# opencv_contrib_python.libs
# opencv_python-4.6.0.66.dist-info
# opencv_python_headless-4.6.0.66.dist-info
# opencv_python_headless.libs
# opencv_python.libs
# OpenGL
# openpyxl
# openpyxl-3.0.10.dist-info
# opt_einsum
# opt_einsum-3.3.0.dist-info
# osgeo
# osqp
# osqp-0.6.2.post0.dist-info
# osqppurepy
# osr.py
# packaging
# packaging-21.3.dist-info
# palettable
# palettable-3.3.0.dist-info
# pandas
# pandas-1.3.5.dist-info
# pandas_datareader
# pandas_datareader-0.9.0.dist-info
# pandas_gbq
# pandas_gbq-0.13.3.dist-info
# pandas_profiling
# pandas_profiling-1.4.1.dist-info
# pandocfilters-1.5.0.dist-info
# pandocfilters.py
# panel
# panel-0.12.1.dist-info
# param
# param-1.12.2.dist-info
# parso
# parso-0.8.3.dist-info
# partd
# partd-1.3.0.dist-info
# past
# pasta
# pastel
# pastel-0.2.1.dist-info
# pathlib-1.0.1.dist-info
# pathlib.py
# pathy
# pathy-0.6.2.dist-info
# patsy
# patsy-0.5.3.dist-info
# pep517
# pep517-0.13.0.dist-info
# pexpect
# pexpect-4.8.0.dist-info
# pickleshare-0.7.5.dist-info
# pickleshare.py
# PIL
# Pillow-7.1.2.dist-info
# Pillow.libs
# pip
# pip-21.1.3.dist-info
# piptools
# pip_tools-6.2.0.dist-info
# pkg_resources
# plotly
# plotly-5.5.0.dist-info
# _plotly_future_
# _plotly_utils
# plotlywidget
# plotnine
# plotnine-0.8.0.dist-info
# pluggy
# pluggy-0.7.1.dist-info
# pooch
# pooch-1.6.0.dist-info
# portpicker-1.3.9.dist-info
# portpicker.py
# prefetch_generator
# prefetch_generator-1.0.1.dist-info
# preshed
# preshed-3.0.8.dist-info
# prettytable
# prettytable-3.4.1.dist-info
# progressbar
# progressbar2-3.38.0.dist-info
# promise
# promise-2.3.dist-info
# prompt_toolkit
# prompt_toolkit-2.0.10.dist-info
# prophet
# prophet-1.1.1.dist-info
# prophet.libs
# protobuf-3.17.3.dist-info
# protobuf-3.17.3-py3.7-nspkg.pth
# psutil
# psutil-5.4.8.dist-info
# psycopg2
# psycopg2-2.9.5.dist-info
# ptyprocess
# ptyprocess-0.7.0.dist-info
# pvectorc.cpython-37m-x86_64-linux-gnu.so
# py
# py-1.11.0.dist-info
# pyarrow
# pyarrow-6.0.1.dist-info
# pyasn1
# pyasn1-0.4.8.dist-info
# pyasn1_modules
# pyasn1_modules-0.2.8.dist-info
# __pycache__
# pycocotools
# pycocotools-2.0.5.dist-info
# pycparser
# pycparser-2.21.dist-info
# pyct
# pyct-0.4.8.dist-info
# pydantic
# pydantic-1.10.2.dist-info
# pydata_google_auth
# pydata_google_auth-1.4.0.dist-info
# pydot-1.3.0.dist-info
# pydot_ng
# pydot_ng-2.0.0.dist-info
# pydotplus
# pydotplus-2.0.2.dist-info
# pydot.py
# pydrive
# PyDrive-1.3.1.dist-info
# pyemd
# pyemd-0.5.1.dist-info
# pyerfa-2.0.0.1.dist-info
# pygments
# Pygments-2.6.1.dist-info
# pylab.py
# pylev
# pylev-1.4.0.dist-info
# pymc
# pymc-4.1.4.dist-info
# pymeeus
# PyMeeus-0.5.11.dist-info
# pymongo
# pymongo-4.3.2.dist-info
# pymystem3
# pymystem3-0.2.0.dist-info
# PyOpenGL-3.1.6.dist-info
# pyparsing
# pyparsing-3.0.9.dist-info
# pyrsistent
# pyrsistent-0.18.1.dist-info
# _pyrsistent_version.py
# pysimdjson-3.2.0.dist-info
# pysndfile
# pysndfile-1.3.8.dist-info
# PySocks-1.7.1.dist-info
# pystan-3.3.0.dist-info
# _pytest
# pytest-3.6.4.dist-info
# pytest.py
# python_apt-0.0.0.egg-info
# python_dateutil-2.8.2.dist-info
# python_louvain-0.16.dist-info
# python_slugify-6.1.2.dist-info
# python_utils
# python_utils-3.3.3.dist-info
# pytz
# pytz-2022.5.dist-info
# pyviz_comms
# pyviz_comms-2.2.1.dist-info
# PyWavelets-1.3.0.dist-info
# pywt
# pyximport
# PyYAML-6.0.dist-info
# pyzmq-23.2.1.dist-info
# pyzmq.libs
# qdldl-0.1.5.post2.dist-info
# qdldl.cpython-37m-x86_64-linux-gnu.so
# qudida
# qudida-0.0.4.dist-info
# regex
# regex-2022.6.2.dist-info
# requests
# requests-2.23.0.dist-info
# requests_oauthlib
# requests_oauthlib-1.3.1.dist-info
# resampy
# resampy-0.4.2.dist-info
# _rinterface_cffi_abi.py
# _rinterface_cffi_api.abi3.so
# rpy2
# rpy2-3.5.5.dist-info
# rsa
# rsa-4.9.dist-info
# samples
# scikit_image-0.18.3.dist-info
# scikit_image.libs
# scikit_learn-1.0.2.dist-info
# scikit_learn.libs
# scipy
# scipy-1.7.3.dist-info
# scipy.libs
# scs
# scs-3.2.0.dist-info
# _scs_direct.cpython-37m-x86_64-linux-gnu.so
# _scs_indirect.cpython-37m-x86_64-linux-gnu.so
# scs.libs
# seaborn
# seaborn-0.11.2.dist-info
# send2trash
# Send2Trash-1.8.0.dist-info
# setuptools
# setuptools-57.4.0.dist-info
# setuptools_git
# setuptools_git-1.2.dist-info
# shapely
# Shapely-1.8.5.post1.dist-info
# Shapely.libs
# simdjson
# six-1.15.0.dist-info
# six.py
# skimage
# sklearn
# sklearn_pandas
# sklearn_pandas-1.8.0.dist-info
# slugify
# smart_open
# smart_open-5.2.1.dist-info
# snowballstemmer
# snowballstemmer-2.2.0.dist-info
# sockshandler.py
# socks.py
# sortedcontainers
# sortedcontainers-2.4.0.dist-info
# soundfile-0.11.0.dist-info
# _soundfile.py
# soundfile.py
# spacy
# spacy-3.4.2.dist-info
# spacy_legacy
# spacy_legacy-3.0.10.dist-info
# spacy_loggers
# spacy_loggers-1.0.3.dist-info
# sphinx
# Sphinx-1.8.6.dist-info
# sphinxcontrib
# sphinxcontrib_serializinghtml-1.1.5.dist-info
# sphinxcontrib_serializinghtml-1.1.5-py3.9-nspkg.pth
# sphinxcontrib_websupport-1.2.4.dist-info
# sphinxcontrib_websupport-1.2.4-py3.8-nspkg.pth
# sql
# sqlalchemy
# SQLAlchemy-1.4.42.dist-info
# sqlparse
# sqlparse-0.4.3.dist-info
# srsly
# srsly-2.4.5.dist-info
# stan
# statsmodels
# statsmodels-0.12.2.dist-info
# sympy
# sympy-1.7.1.dist-info
# tables
# tables-3.7.0.dist-info
# tables.libs
# tabulate-0.8.10.dist-info
# tabulate.py
# tblib
# tblib-1.7.0.dist-info
# tenacity
# tenacity-8.1.0.dist-info
# tensorboard
# tensorboard-2.9.1.dist-info
# tensorboard_data_server
# tensorboard_data_server-0.6.1.dist-info
# tensorboard_plugin_wit
# tensorboard_plugin_wit-1.8.1.dist-info
# tensorflow
# tensorflow-2.9.2.dist-info
# tensorflow_datasets
# tensorflow_datasets-4.6.0.dist-info
# tensorflow_estimator
# tensorflow_estimator-2.9.0.dist-info
# tensorflow_gcs_config
# tensorflow_gcs_config-2.9.1.dist-info
# tensorflow_hub
# tensorflow_hub-0.12.0.dist-info
# tensorflow_io_gcs_filesystem
# tensorflow_io_gcs_filesystem-0.27.0.dist-info
# tensorflow_metadata
# tensorflow_metadata-1.10.0.dist-info
# tensorflow_probability
# tensorflow_probability-0.16.0.dist-info
# termcolor
# termcolor-2.0.1.dist-info
# terminado
# terminado-0.13.3.dist-info
# testpath
# testpath-0.6.0.dist-info
# tests
# textblob
# textblob-0.15.3.dist-info
# text_unidecode
# text_unidecode-1.3.dist-info
# thinc
# thinc-8.1.5.dist-info
# threadpoolctl-3.1.0.dist-info
# threadpoolctl.py
# tifffile
# tifffile-2021.11.2.dist-info
# tlz
# toml
# toml-0.10.2.dist-info
# tomli
# tomli-2.0.1.dist-info
# toolz
# toolz-0.12.0.dist-info
# torch
# torch-1.12.1+cu113.dist-info
# torchaudio
# torchaudio-0.12.1+cu113.dist-info
# torchgen
# torchsummary
# torchsummary-1.5.1.dist-info
# torchtext
# torchtext-0.13.1.dist-info
# torchvision
# torchvision-0.13.1+cu113.dist-info
# torchvision.libs
# tornado
# tornado-5.1.1.dist-info
# tqdm
# tqdm-4.64.1.dist-info
# traitlets
# traitlets-5.1.1.dist-info
# tree
# tweepy
# tweepy-3.10.0.dist-info
# typeguard
# typeguard-2.7.1.dist-info
# typer
# typer-0.4.2.dist-info
# typing_extensions-4.1.1.dist-info
# typing_extensions.py
# tzlocal
# tzlocal-1.5.1.dist-info
# unification
# uritemplate
# uritemplate-3.0.1.dist-info
# urllib3
# urllib3-1.24.3.dist-info
# vega_datasets
# vega_datasets-0.9.0.dist-info
# vis
# wasabi
# wasabi-0.10.1.dist-info
# wcwidth
# wcwidth-0.2.5.dist-info
# webargs
# webargs-8.2.0.dist-info
# webencodings
# webencodings-0.5.1.dist-info
# werkzeug
# Werkzeug-1.0.1.dist-info
# wheel
# wheel-0.37.1.dist-info
# widgetsnbextension
# widgetsnbextension-3.6.1.dist-info
# wordcloud
# wordcloud-1.8.2.2.dist-info
# wrapt
# wrapt-1.14.1.dist-info
# xarray
# xarray-0.20.2.dist-info
# xarray_einstats
# xarray_einstats-0.2.2.dist-info
# xgboost
# xgboost-0.90.dist-info
# xlrd
# xlrd-1.1.0.dist-info
# xlwt
# xlwt-1.3.0.dist-info
# yaml
# _yaml
# yarl
# yarl-1.8.1.dist-info
# yellowbrick
# yellowbrick-1.5.dist-info
# zict
# zict-2.2.0.dist-info
# zipp
# zipp-3.10.0.dist-info
# zmq

# %%
import sys
sys.path.append("/usr/local/lib/python3.7/site-packages")

# %%
# !conda config --add channels bioconda

# !conda config --add channels conda-forge

# %%
# !conda install trinity -y
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - trinity
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bowtie-1.3.1               |   py37h8296c00_1         955 KB  bioconda
#     bowtie2-2.3.5.1            |   py37he513fc3_0        12.0 MB  bioconda
#     bzip2-1.0.8                |       h7f98852_4         484 KB  conda-forge
#     ca-certificates-2022.9.24  |       ha878542_0         150 KB  conda-forge
#     certifi-2022.9.24          |     pyhd8ed1ab_0         155 KB  conda-forge
#     conda-22.9.0               |   py37h89c1867_1         960 KB  conda-forge
#     icu-58.2                   |    hf484d3e_1000        22.6 MB  conda-forge
#     jemalloc-5.2.1             |       h9c3ff4c_6          51 KB  conda-forge
#     kmer-jellyfish-2.3.0       |       h9f5acd7_3         364 KB  bioconda
#     libblas-3.9.0              |15_linux64_openblas          12 KB  conda-forge
#     libboost-1.67.0            |       h46d08c1_4        13.0 MB
#     libcblas-3.9.0             |15_linux64_openblas          12 KB  conda-forge
#     libgfortran-ng-12.2.0      |      h69a702a_19          22 KB  conda-forge
#     libgfortran5-12.2.0        |      h337968e_19         1.8 MB  conda-forge
#     libjemalloc-5.2.1          |       h9c3ff4c_6         1.6 MB  conda-forge
#     liblapack-3.9.0            |15_linux64_openblas          12 KB  conda-forge
#     libnsl-2.0.0               |       h7f98852_0          31 KB  conda-forge
#     libopenblas-0.3.20         |pthreads_h78a6416_0        10.1 MB  conda-forge
#     numpy-1.21.6               |   py37h976b520_0         6.1 MB  conda-forge
#     openjdk-8.0.332            |       h166bdaf_0        97.8 MB  conda-forge
#     perl-5.32.1                | 2_h7f98852_perl5        14.4 MB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     salmon-0.13.1              |       h86b0361_0         4.2 MB  bioconda
#     samtools-1.3.1             |                0         1.5 MB  bioconda
#     tbb-2020.2                 |       h4bd325d_4         1.5 MB  conda-forge
#     trimmomatic-0.39           |       hdfd78af_2         144 KB  bioconda
#     trinity-2.8.5              |       h8b12597_5         5.2 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:       194.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   bowtie             bioconda/linux-64::bowtie-1.3.1-py37h8296c00_1 None
#   bowtie2            bioconda/linux-64::bowtie2-2.3.5.1-py37he513fc3_0 None
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h7f98852_4 None
#   icu                conda-forge/linux-64::icu-58.2-hf484d3e_1000 None
#   jemalloc           conda-forge/linux-64::jemalloc-5.2.1-h9c3ff4c_6 None
#   kmer-jellyfish     bioconda/linux-64::kmer-jellyfish-2.3.0-h9f5acd7_3 None
#   libblas            conda-forge/linux-64::libblas-3.9.0-15_linux64_openblas None
#   libboost           pkgs/main/linux-64::libboost-1.67.0-h46d08c1_4 None
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-15_linux64_openblas None
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.2.0-h69a702a_19 None
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.2.0-h337968e_19 None
#   libjemalloc        conda-forge/linux-64::libjemalloc-5.2.1-h9c3ff4c_6 None
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-15_linux64_openblas None
#   libnsl             conda-forge/linux-64::libnsl-2.0.0-h7f98852_0 None
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.20-pthreads_h78a6416_0 None
#   numpy              conda-forge/linux-64::numpy-1.21.6-py37h976b520_0 None
#   openjdk            conda-forge/linux-64::openjdk-8.0.332-h166bdaf_0 None
#   perl               conda-forge/linux-64::perl-5.32.1-2_h7f98852_perl5 None
#   python_abi         conda-forge/linux-64::python_abi-3.7-2_cp37m None
#   salmon             bioconda/linux-64::salmon-0.13.1-h86b0361_0 None
#   samtools           bioconda/linux-64::samtools-1.3.1-0 None
#   tbb                conda-forge/linux-64::tbb-2020.2-h4bd325d_4 None
#   trimmomatic        bioconda/noarch::trimmomatic-0.39-hdfd78af_2 None
#   trinity            bioconda/linux-64::trinity-2.8.5-h8b12597_5 None
#
# The following packages will be UPDATED:
#
#   conda              pkgs/main::conda-22.9.0-py37h06a4308_0 --> conda-forge::conda-22.9.0-py37h89c1867_1 None
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2022.10.11~ --> conda-forge::ca-certificates-2022.9.24-ha878542_0 None
#   certifi            pkgs/main/linux-64::certifi-2022.9.24~ --> conda-forge/noarch::certifi-2022.9.24-pyhd8ed1ab_0 None
#
#
#
# Downloading and Extracting Packages
# salmon-0.13.1        | 4.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.34s/it]
# perl-5.32.1          | 14.4 MB   | : 100% 1.0/1 [00:04<00:00,  4.25s/it]
# bowtie2-2.3.5.1      | 12.0 MB   | : 100% 1.0/1 [00:02<00:00,  2.76s/it]
# certifi-2022.9.24    | 155 KB    | : 100% 1.0/1 [00:00<00:00, 10.20it/s]
# libgfortran5-12.2.0  | 1.8 MB    | : 100% 1.0/1 [00:00<00:00,  1.72it/s]
# numpy-1.21.6         | 6.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.81s/it]
# trinity-2.8.5        | 5.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.48s/it]
# bowtie-1.3.1         | 955 KB    | : 100% 1.0/1 [00:00<00:00,  2.89it/s]
# kmer-jellyfish-2.3.0 | 364 KB    | : 100% 1.0/1 [00:00<00:00,  4.22it/s]
# ca-certificates-2022 | 150 KB    | : 100% 1.0/1 [00:00<00:00,  9.73it/s]
# liblapack-3.9.0      | 12 KB     | : 100% 1.0/1 [00:00<00:00,  6.42it/s]
# python_abi-3.7       | 4 KB      | : 100% 1.0/1 [00:00<00:00,  5.51it/s]
# libboost-1.67.0      | 13.0 MB   | : 100% 1.0/1 [00:03<00:00,  3.77s/it]
# icu-58.2             | 22.6 MB   | : 100% 1.0/1 [00:05<00:00,  5.92s/it]
# samtools-1.3.1       | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  2.44it/s]
# conda-22.9.0         | 960 KB    | : 100% 1.0/1 [00:00<00:00,  2.23it/s]
# libnsl-2.0.0         | 31 KB     | : 100% 1.0/1 [00:00<00:00, 14.10it/s]
# bzip2-1.0.8          | 484 KB    | : 100% 1.0/1 [00:00<00:00,  4.43it/s]
# libblas-3.9.0        | 12 KB     | : 100% 1.0/1 [00:00<00:00, 13.43it/s]
# trimmomatic-0.39     | 144 KB    | : 100% 1.0/1 [00:00<00:00, 10.21it/s]
# openjdk-8.0.332      | 97.8 MB   | : 100% 1.0/1 [00:20<00:00, 20.93s/it]
# libgfortran-ng-12.2. | 22 KB     | : 100% 1.0/1 [00:00<00:00,  6.22it/s]
# libopenblas-0.3.20   | 10.1 MB   | : 100% 1.0/1 [00:02<00:00,  2.45s/it]
# tbb-2020.2           | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.19it/s]
# libjemalloc-5.2.1    | 1.6 MB    | : 100% 1.0/1 [00:00<00:00,  1.97it/s]
# jemalloc-5.2.1       | 51 KB     | : 100% 1.0/1 [00:00<00:00, 10.28it/s]
# libcblas-3.9.0       | 12 KB     | : 100% 1.0/1 [00:00<00:00,  6.58it/s]
# done
# done
# done
# Retrieving notices: ...working... done

# %%
# !Trinity
# Out:
# ###############################################################################
# #
#
#      ______  ____   ____  ____   ____  ______  __ __
#     |      ||    \ |    ||    \ |    ||      ||  |  |
#     |      ||  D  ) |  | |  _  | |  | |      ||  |  |
#     |_|  |_||    /  |  | |  |  | |  | |_|  |_||  ~  |
#       |  |  |    \  |  | |  |  | |  |   |  |  |___, |
#       |  |  |  .  \ |  | |  |  | |  |   |  |  |     |
#       |__|  |__|\_||____||__|__||____|  |__|  |____/
#
#     Trinity-v2.8.5
#
#
# #
# #
# # Required:
# #
# #  --seqType <string>      :type of reads: ('fa' or 'fq')
# #
# #  --max_memory <string>      :suggested max memory to use by Trinity where limiting can be enabled. (jellyfish, sorting, etc)
# #                            provided in Gb of RAM, ie.  '--max_memory 10G'
# #
# #  If paired reads:
# #      --left  <string>    :left reads, one or more file names (separated by commas, no spaces)
# #      --right <string>    :right reads, one or more file names (separated by commas, no spaces)
# #
# #  Or, if unpaired reads:
# #      --single <string>   :single reads, one or more file names, comma-delimited (note, if single file contains pairs, can use flag: --run_as_paired )
# #
# #  Or,
# #      --samples_file <string>         tab-delimited text file indicating biological replicate relationships.
# #                                   ex.
# #                                        cond_A    cond_A_rep1    A_rep1_left.fq    A_rep1_right.fq
# #                                        cond_A    cond_A_rep2    A_rep2_left.fq    A_rep2_right.fq
# #                                        cond_B    cond_B_rep1    B_rep1_left.fq    B_rep1_right.fq
# #                                        cond_B    cond_B_rep2    B_rep2_left.fq    B_rep2_right.fq
# #
# #                      # if single-end instead of paired-end, then leave the 4th column above empty.
# #
# ####################################
# ##  Misc:  #########################
# #
# #  --include_supertranscripts      :yield supertranscripts fasta and gtf files as outputs.
# #
# #  --SS_lib_type <string>          :Strand-specific RNA-Seq read orientation.
# #                                   if paired: RF or FR,
# #                                   if single: F or R.   (dUTP method = RF)
# #                                   See web documentation.
# #
# #  --CPU <int>                     :number of CPUs to use, default: 2
# #  --min_contig_length <int>       :minimum assembled contig length to report
# #                                   (def=200)
# #
# #  --long_reads <string>           :fasta file containing error-corrected or circular consensus (CCS) pac bio reads
# #                                   (** note: experimental parameter **, this functionality continues to be under development)
# #
# #  --genome_guided_bam <string>    :genome guided mode, provide path to coordinate-sorted bam file.
# #                                   (see genome-guided param section under --show_full_usage_info)
# #
# #  --jaccard_clip                  :option, set if you have paired reads and
# #                                   you expect high gene density with UTR
# #                                   overlap (use FASTQ input file format
# #                                   for reads).
# #                                   (note: jaccard_clip is an expensive
# #                                   operation, so avoid using it unless
# #                                   necessary due to finding excessive fusion
# #                                   transcripts w/o it.)
# #
# #  --trimmomatic                   :run Trimmomatic to quality trim reads
# #                                        see '--quality_trimming_params' under full usage info for tailored settings.
# #
# #
# #  --no_normalize_reads            :Do *not* run in silico normalization of reads. Defaults to max. read coverage of 200.
# #                                       see '--normalize_max_read_cov' under full usage info for tailored settings.
# #                                       (note, as of Sept 21, 2016, normalization is on by default)
# #
# #  --no_distributed_trinity_exec   :do not run Trinity phase 2 (assembly of partitioned reads), and stop after generating command list.
# #
# #
# #  --output <string>               :name of directory for output (will be
# #                                   created if it doesn't already exist)
# #                                   default( your current working directory: "/content/trinity_out_dir"
# #                                    note: must include 'trinity' in the name as a safety precaution! )
# #
# #  --workdir <string>              :where Trinity phase-2 assembly computation takes place (defaults to --output setting).
# #                                  (can set this to a node-local drive or RAM disk)
# #
# #  --full_cleanup                  :only retain the Trinity fasta file, rename as ${output_dir}.Trinity.fasta
# #
# #  --cite                          :show the Trinity literature citation
# #
# #  --verbose                       :provide additional job status info during the run.
# #
# #  --version                       :reports Trinity version (Trinity-v2.8.5) and exits.
# #
# #  --show_full_usage_info          :show the many many more options available for running Trinity (expert usage).
# #
# #
# ###############################################################################
# #
# #  *Note, a typical Trinity command might be:
# #
# #        Trinity --seqType fq --max_memory 50G --left reads_1.fq  --right reads_2.fq --CPU 6
# #
# #            (if you have multiple samples, use --samples_file ... see above for details)
# #
# #    and for Genome-guided Trinity, provide a coordinate-sorted bam:
# #
# #        Trinity --genome_guided_bam rnaseq_alignments.csorted.bam --max_memory 50G
# #                --genome_guided_max_intron 10000 --CPU 6
# #
# #     see: /usr/local/opt/trinity-2.8.5/sample_data/test_Trinity_Assembly/
# #          for sample data and 'runMe.sh' for example Trinity execution
# #
# #     For more details, visit: http://trinityrnaseq.github.io
# #
# ###############################################################################

# %%
# %matplotlib inline

from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, combinations
fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111, projection='3d')




# Plot Points

# samples within the cube
X_inside = np.array([[0,0,0],[0.2,0.2,0.2],[0.1, -0.1, -0.3]])

X_outside = np.array([[-1.2,0.3,-0.3],[0.8,-0.82,-0.9],[1, 0.6, -0.7],
                  [0.8,0.7,0.2],[0.7,-0.8,-0.45],[-0.3, 0.6, 0.9],
                  [0.7,-0.6,-0.8]])

for row in X_inside:
    ax.scatter(row[0], row[1], row[2], color="r", s=50, marker='^')

for row in X_outside:
    ax.scatter(row[0], row[1], row[2], color="k", s=50)

# Plot Cube
h = [-0.5, 0.5]
for s, e in combinations(np.array(list(product(h,h,h))), 2):
    if np.sum(np.abs(s-e)) == h[1]-h[0]:
        ax.plot3D(*zip(s,e), color="g")

ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)
ax.set_zlim(-1.5, 1.5)

plt.show()
